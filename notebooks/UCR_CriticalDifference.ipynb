# %% [markdown]
# # Critical Difference Plots

# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy.stats import wilcoxon
import sys
sys.path.append("..")
from evaluation import *
from ucr import *

# %% [markdown]
# ## Mean Average Precision

# %%
fac = 0.8
plt.figure(figsize=(fac*12, fac*2))
make_critical_distance_plot("../MAP_ALL.csv", 0.025)
plt.savefig("MAP_ALL.svg", bbox_inches='tight')
# Out:
# ['bottleneck', 'dtw_full', 3.058714694662859e-14] True
# ['bottleneck', 'dope', 1.931111494017333e-11] True
# ['bottleneck', 'wasserstein', 1.5578321262302158e-10] True
# ['wasserstein', 'dtw_full', 5.4352402081817485e-08] True
# ['dtw_crit', 'dtw_full', 8.143547164565396e-08] True
# ['bottleneck', 'dtw_crit', 1.5327877961844461e-07] True
# ['euclidean', 'dtw_full', 5.94709154372816e-07] True
# ['dope', 'dtw_full', 1.332938540685356e-06] True
# ['wasserstein', 'dope', 0.003947615691317688] False
# ['bottleneck', 'euclidean', 0.005087186207369312] False
# ['wasserstein', 'dtw_crit', 0.029200919053752324] False
# ['euclidean', 'dtw_crit', 0.08489391667860334] False
# ['euclidean', 'dope', 0.15224509528931424] False
# ['euclidean', 'wasserstein', 0.7863071346779685] False
# ['dope', 'dtw_crit', 0.8120245945792482] False

# %% [markdown]
# ## Mean Rank

# %%
fac = 0.8
plt.figure(figsize=(fac*12, fac*2))
make_critical_distance_plot("../MR_ALL.csv", 0.025)
plt.savefig("MR_ALL.svg", bbox_inches='tight')
# Out:
# ['dtw_full', 'bottleneck', 1.2803997447343917e-12] True
# ['dtw_full', 'dope', 2.761040809369511e-10] True
# ['dtw_full', 'wasserstein', 1.06864063448817e-08] True
# ['dtw_crit', 'bottleneck', 1.603225453389251e-06] True
# ['dtw_full', 'dtw_crit', 7.4485764630254525e-06] True
# ['dtw_full', 'euclidean', 1.638360391940748e-05] True
# ['dope', 'bottleneck', 0.0009120768101723441] True
# ['wasserstein', 'bottleneck', 0.0017220114283937056] True
# ['dtw_crit', 'wasserstein', 0.0017931285384861293] True
# ['euclidean', 'bottleneck', 0.004467997058778848] False
# ['dtw_crit', 'dope', 0.010572440109641073] False
# ['euclidean', 'wasserstein', 0.3161492017042057] False
# ['dtw_crit', 'euclidean', 0.3307199899242742] False
# ['euclidean', 'dope', 0.6074728115938424] False
# ['dope', 'wasserstein', 0.7844760290141257] False

# %% [markdown]
# # 1NN

# %%
fac = 0.8
plt.figure(figsize=(fac*12, fac*2))
make_critical_distance_plot("../1NN_ALL.csv", 0.025)
plt.savefig("1NN_ALL.svg", bbox_inches='tight')
# Out:
# ['dtw_full', 'bottleneck', 6.115150229094405e-16] True
# ['dtw_crit', 'bottleneck', 1.0610160851658572e-11] True
# ['wasserstein', 'bottleneck', 1.0874205030128297e-11] True
# ['dope', 'bottleneck', 1.1129480314186025e-10] True
# ['dtw_full', 'wasserstein', 1.18596742947454e-08] True
# ['dtw_full', 'dope', 1.6633680412576907e-08] True
# ['euclidean', 'bottleneck', 2.957966510836377e-07] True
# ['dtw_crit', 'wasserstein', 3.2209329895219665e-05] True
# ['dtw_full', 'euclidean', 5.751942109144737e-05] True
# ['dtw_full', 'dtw_crit', 0.00018763896039909945] True
# ['dtw_crit', 'dope', 0.003521967347674227] True
# ['dope', 'wasserstein', 0.025693805934557126] False
# ['euclidean', 'wasserstein', 0.03615528840307076] False
# ['dtw_crit', 'euclidean', 0.12446694518168848] False
# ['dope', 'euclidean', 0.9876648283974664] False

# %% [markdown]
# ## Mean Reciprocal Rank

# %%
fac = 0.8
plt.figure(figsize=(fac*12, fac*2))
make_critical_distance_plot("../MRR_ALL.csv", 0.025)
plt.savefig("MRR_ALL.svg", bbox_inches='tight')
# Out:
# ['bottleneck', 'dtw_full', 1.1069723969181524e-15] True
# ['bottleneck', 'dtw_crit', 3.711189626422074e-12] True
# ['bottleneck', 'wasserstein', 5.122842183680484e-10] True
# ['dope', 'dtw_full', 1.286714609606703e-09] True
# ['bottleneck', 'dope', 1.5940105641492378e-09] True
# ['wasserstein', 'dtw_full', 2.6404884585788967e-09] True
# ['bottleneck', 'euclidean', 6.72484572992962e-07] True
# ['wasserstein', 'dtw_crit', 2.844768387463317e-05] True
# ['dtw_crit', 'dtw_full', 4.090380868683288e-05] True
# ['euclidean', 'dtw_full', 4.769542358271404e-05] True
# ['dope', 'dtw_crit', 0.003549872798591727] True
# ['wasserstein', 'dope', 0.02765298043327618] False
# ['wasserstein', 'euclidean', 0.029554152583517346] False
# ['euclidean', 'dtw_crit', 0.117623989569417] False
# ['euclidean', 'dope', 0.8809034966479191] False
